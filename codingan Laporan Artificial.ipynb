# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
from keras.datasets import mnist
objects=mnist
(train_img,train_lab),(test_img,test_lab)=objects.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.imshow(train_img[0])
print(train_lab[0])
# Out:
# 5

# %%
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.imshow(train_img[i],cmap='gray_r')
  plt.title("Digit : {}".format(train_lab[i]))
  plt.subplots_adjust(hspace=0.5)
  plt.axis('off')

# %%
print('Training images shape : ',train_img.shape)
print('Testing images shape :',test_img.shape)
# Out:
# Training images shape :  (60000, 28, 28)
# Testing images shape : (10000, 28, 28)

# %%
train_img=train_img/225.0
test_img=test_img/225.0

# %%
from keras.models import Sequential
from keras.layers import Flatten,Dense
model=Sequential()
input_layer= Flatten(input_shape=(28,28))
model.add(input_layer)
hidden_layer1=Dense(512,activation='relu')
model.add(hidden_layer1)
hidden_layer2=Dense(512,activation='relu')
model.add(hidden_layer2)
output_layer=Dense(10,activation='softmax')
model.add(output_layer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling the sequential model
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics =['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-847ca47d5c8a> in <module>
#       1 #compiling the sequential model
# ----> 2 model.compile(optimizer = 'adam',
#       3               loss = 'sparse_categorical_crossentropy',
#       4               metrics =['accuracy'])
#
# NameError: name 'model' is not defined

# %%
plt.imshow(test_img[1],cmap='gray_r')
plt.title('actual value: {}'.format(test_lab[1]))
prediction=model.predict(test_img)
plt.axis('off')
print('predicted value: ',np.argmax(prediction[0]))
if(test_lab[0]==(np.argmax(prediction[0]))):
  print('Successfull prediction')
else:
    print('Unsuccessful prediction')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1ab6ebbff124> in <module>
#       1 plt.imshow(test_img[1],cmap='gray_r')
#       2 plt.title('actual value: {}'.format(test_lab[1]))
# ----> 3 prediction=model.predict(test_img)
#       4 plt.axis('off')
#       5 print('predicted value: ',np.argmax(prediction[0]))
#
# NameError: name 'model' is not defined

# %%
plt.imshow(test_img[100],cmap='gray_r')
plt.title('actual value: {}'.format(test_lab[100]))
prediction=model.predict(test_img)
plt.axis('off')
print('predicted value: ',np.argmax(prediction[100]))
if(test_lab[0]==(np.argmax(prediction[0]))):
  print('Successfull prediction')
else:
    print('Unsuccessful prediction')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fa2c11cdbb46> in <module>
#       1 plt.imshow(test_img[100],cmap='gray_r')
#       2 plt.title('actual value: {}'.format(test_lab[100]))
# ----> 3 prediction=model.predict(test_img)
#       4 plt.axis('off')
#       5 print('predicted value: ',np.argmax(prediction[100]))
#
# NameError: name 'model' is not defined
